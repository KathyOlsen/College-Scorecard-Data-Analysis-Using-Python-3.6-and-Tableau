# %%
import pandas as pd
Location = "Most-Recent-Cohorts-Treasury-Elements.csv"
df = pd.read_csv(Location)
df.head()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
#    UNITID    OPEID  OPEID6                               INSTNM  COUNT_ED  \
# 0  100654   100200    1002             Alabama A & M University       NaN
# 1  100663   105200    1052  University of Alabama at Birmingham       NaN
# 2  100690  2503400   25034                   Amridge University       NaN
# 3  100706   105500    1055  University of Alabama in Huntsville       NaN
# 4  100724   100500    1005             Alabama State University       NaN
#
#             AGEGE24         PCT_WHITE         PCT_BLACK         PCT_ASIAN  \
# ...

# %%
len(df)
# Out:
# 7593

# %%
dfdrop=df
dfdrop=dfdrop.dropna(axis=1, how='all') #drop null columns
dfdrop=dfdrop.drop('OPEID6', axis=1) #drop institutional ID
dfdrop=dfdrop.drop('OPEID', axis=1) #drop institutional ID
dfdrop=dfdrop.drop('UNITID', axis=1) #drop institutional ID
dfdrop.head()
# Out:
#                                 INSTNM           AGEGE24         PCT_WHITE  \
# 0             Alabama A & M University  0.07999999821186  46.8400001525878
# 1  University of Alabama at Birmingham  0.25999999046325  69.0199966430664
# 2                   Amridge University  0.82999998331069  70.8799972534179
# 3  University of Alabama in Huntsville  0.28999999165534  76.3799972534179
# 4             Alabama State University  0.10999999940395  42.6899986267089
#
#           PCT_BLACK         PCT_ASIAN      PCT_HISPANIC            PCT_BA  \
# 0  47.9799995422363  1.48000001907348  3.78999996185302                13
# 1  27.7600002288818  1.10000002384185  2.02999997138977  15.9300003051757
# 2  22.5300006866455  1.28999996185302  6.94000005722046  13.2299995422363
# 3  18.9799995422363  1.41999995708465  2.54999995231628  17.6700000762939
# 4  52.3199996948242  1.40999996662139  4.09000015258789  11.8100004196167
#
# ...

# %%
dfdrop=dfdrop.drop_duplicates()

# %%
len(dfdrop)
# Out:
# 7531

# %%
dfdrop.describe()
# Out:
#                   INSTNM           AGEGE24          PCT_WHITE  \
# count               7531              5407               5407
# unique              7431               102               3029
# top     Bryan University  0.49000000953674  PrivacySuppressed
# freq                   5               102                 95
#
#                 PCT_BLACK          PCT_ASIAN       PCT_HISPANIC  \
# count                5407               5407               5407
# unique               2316               1001               2071
# top     PrivacySuppressed  PrivacySuppressed  PrivacySuppressed
# freq                   95                 95                 95
#
#                    PCT_BA      PCT_GRAD_PROF        PCT_BORN_US  \
# count                5407               5407               5407
# unique               1610               1175               2086
# top     PrivacySuppressed  PrivacySuppressed  PrivacySuppressed
# freq                  133                133                133
#
# ...

# %%
dfdrop.dtypes
# Out:
# INSTNM                        object
# AGEGE24                       object
# PCT_WHITE                     object
# PCT_BLACK                     object
# PCT_ASIAN                     object
# PCT_HISPANIC                  object
# PCT_BA                        object
# PCT_GRAD_PROF                 object
# PCT_BORN_US                   object
# MEDIAN_HH_INC                 object
# POVERTY_RATE                  object
# UNEMP_RATE                    object
# LN_MEDIAN_HH_INC              object
# COUNT_NWNE_P10                object
# COUNT_WNE_P10                 object
# MN_EARN_WNE_P10               object
# MD_EARN_WNE_P10               object
# PCT10_EARN_WNE_P10            object
# PCT25_EARN_WNE_P10            object
# PCT75_EARN_WNE_P10            object
# PCT90_EARN_WNE_P10            object
# SD_EARN_WNE_P10               object
# COUNT_WNE_INC1_P10            object
# COUNT_WNE_INC2_P10            object
# COUNT_WNE_INC3_P10            object
# ...

# %%
# Create dataframe with one column to remain object type.
dfdropA = dfdrop[['INSTNM']]
dfdropA.head()
# Out:
#                                 INSTNM
# 0             Alabama A & M University
# 1  University of Alabama at Birmingham
# 2                   Amridge University
# 3  University of Alabama in Huntsville
# 4             Alabama State University

# %%
# Create dataframe with remaining columns.
dfdropB=dfdrop
dfdropB=dfdropB.drop('INSTNM', axis=1) 
dfdropB.head()
# Out:
#             AGEGE24         PCT_WHITE         PCT_BLACK         PCT_ASIAN  \
# 0  0.07999999821186  46.8400001525878  47.9799995422363  1.48000001907348
# 1  0.25999999046325  69.0199966430664  27.7600002288818  1.10000002384185
# 2  0.82999998331069  70.8799972534179  22.5300006866455  1.28999996185302
# 3  0.28999999165534  76.3799972534179  18.9799995422363  1.41999995708465
# 4  0.10999999940395  42.6899986267089  52.3199996948242  1.40999996662139
#
#        PCT_HISPANIC            PCT_BA     PCT_GRAD_PROF       PCT_BORN_US  \
# 0  3.78999996185302                13   6.8600001335144  94.7399978637695
# 1  2.02999997138977  15.9300003051757  8.55000019073486              96.5
# 2  6.94000005722046  13.2299995422363  7.01000022888183  94.0899963378906
# 3  2.54999995231628  17.6700000762939  8.90999984741211  95.2699966430664
# 4  4.09000015258789  11.8100004196167  6.76000022888183  94.5299987792968
#
#   MEDIAN_HH_INC      POVERTY_RATE        ...        PCT25_EARN_WNE_P8  \
# ...

# %%
# Convert all 'PrivacySuppressed' entries to value of 0 and convert all columns to float types.
dfdropB.replace('PrivacySuppressed',0,inplace=True)
dfdropB=dfdropB.astype(float)
dfdropB.head()
# Out:
#    AGEGE24  PCT_WHITE  PCT_BLACK  PCT_ASIAN  PCT_HISPANIC  PCT_BA  \
# 0     0.08  46.840000  47.980000       1.48          3.79   13.00
# 1     0.26  69.019997  27.760000       1.10          2.03   15.93
# 2     0.83  70.879997  22.530001       1.29          6.94   13.23
# 3     0.29  76.379997  18.980000       1.42          2.55   17.67
# 4     0.11  42.689999  52.320000       1.41          4.09   11.81
#
#    PCT_GRAD_PROF  PCT_BORN_US  MEDIAN_HH_INC  POVERTY_RATE    ...      \
# 0           6.86    94.739998       49720.22     14.880000    ...
# 1           8.55    96.500000       55735.22     10.910000    ...
# 2           7.01    94.089996       53683.70     10.650000    ...
# 3           8.91    95.269997       58688.62      9.370000    ...
# 4           6.76    94.529999       46065.20     16.959999    ...
#
#    PCT25_EARN_WNE_P8  PCT75_EARN_WNE_P8  PCT90_EARN_WNE_P8  SD_EARN_WNE_P8  \
# 0            15100.0            38700.0            60700.0         21500.0
# ...

# %%
# Join the two sub-tables back together.
df1=dfdropA.join(dfdropB)
df1.head()
# Out:
#                                 INSTNM  AGEGE24  PCT_WHITE  PCT_BLACK  \
# 0             Alabama A & M University     0.08  46.840000  47.980000
# 1  University of Alabama at Birmingham     0.26  69.019997  27.760000
# 2                   Amridge University     0.83  70.879997  22.530001
# 3  University of Alabama in Huntsville     0.29  76.379997  18.980000
# 4             Alabama State University     0.11  42.689999  52.320000
#
#    PCT_ASIAN  PCT_HISPANIC  PCT_BA  PCT_GRAD_PROF  PCT_BORN_US  MEDIAN_HH_INC  \
# 0       1.48          3.79   13.00           6.86    94.739998       49720.22
# 1       1.10          2.03   15.93           8.55    96.500000       55735.22
# 2       1.29          6.94   13.23           7.01    94.089996       53683.70
# 3       1.42          2.55   17.67           8.91    95.269997       58688.62
# 4       1.41          4.09   11.81           6.76    94.529999       46065.20
#
#      ...      PCT25_EARN_WNE_P8  PCT75_EARN_WNE_P8  PCT90_EARN_WNE_P8  \
# ...

# %%
df1.to_csv('df1_Most_Recent_Cohort_Treasury_Elements.csv',index=False)

# %%
df1.describe()
# Out:
#            AGEGE24    PCT_WHITE    PCT_BLACK    PCT_ASIAN  PCT_HISPANIC  \
# count  5407.000000  5407.000000  5407.000000  5407.000000   5407.000000
# mean      0.422869    74.220028    12.676873     2.965393     12.735866
# std       0.236050    18.597406    12.784777     4.011554     18.516610
# min       0.000000     0.000000     0.000000     0.000000      0.000000
# 25%       0.230000    66.040001     3.930000     0.860000      2.565000
# 50%       0.440000    78.410004     8.110000     1.740000      5.680000
# 75%       0.600000    87.739998    17.225000     3.410000     14.840000
# max       1.000000    98.980003    85.820000    51.720001     99.349998
#
#             PCT_BA  PCT_GRAD_PROF  PCT_BORN_US  MEDIAN_HH_INC  POVERTY_RATE  \
# count  5407.000000    5407.000000  5407.000000    5407.000000   5407.000000
# mean     13.972889       7.655989    86.694259   56869.473795     10.566432
# std       4.615177       3.071462    17.108911   14823.146668      6.985615
# ...

# %%
df1.corr()
# Out:
#                              AGEGE24  PCT_WHITE  PCT_BLACK  PCT_ASIAN  \
# AGEGE24                     1.000000  -0.040066   0.168798   0.072567
# PCT_WHITE                  -0.040066   1.000000  -0.537144  -0.322342
# PCT_BLACK                   0.168798  -0.537144   1.000000  -0.030870
# PCT_ASIAN                   0.072567  -0.322342  -0.030870   1.000000
# PCT_HISPANIC                0.092141  -0.172289  -0.069109   0.187298
# PCT_BA                     -0.090247   0.244186  -0.054710   0.376853
# PCT_GRAD_PROF              -0.139118   0.185330  -0.011735   0.346382
# PCT_BORN_US                 0.089324   0.598498   0.067238  -0.266573
# MEDIAN_HH_INC              -0.032648   0.303775  -0.046339   0.394512
# POVERTY_RATE                0.135620  -0.173576   0.239941  -0.056298
# UNEMP_RATE                  0.219821  -0.215546   0.330331   0.074441
# LN_MEDIAN_HH_INC            0.208879   0.534366   0.109988   0.157315
# ...

# %%
import statsmodels.formula.api as sm
result = sm.ols(formula='MD_EARN_WNE_P10 ~ PCT_BA + PCT_BORN_US + MEDIAN_HH_INC + POVERTY_RATE + UNEMP_RATE + PCT_WHITE + PCT_BLACK + PCT_ASIAN + PCT_HISPANIC-1',data=df1).fit()
result.summary()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        MD_EARN_WNE_P10   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     2082.
# Date:                Sat, 04 Aug 2018   Prob (F-statistic):               0.00
# Time:                        11:50:54   Log-Likelihood:                -59142.
# No. Observations:                5305   AIC:                         1.183e+05
# ...

# %%
result = sm.ols(formula='MD_EARN_WNE_P10 ~ PCT_BA + MEDIAN_HH_INC + PCT_ASIAN - 1',data=df1).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        MD_EARN_WNE_P10   R-squared:                       0.779
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     6238.
# Date:                Sat, 04 Aug 2018   Prob (F-statistic):               0.00
# Time:                        11:50:54   Log-Likelihood:                -59147.
# No. Observations:                5305   AIC:                         1.183e+05
# Df Residuals:                    5302   BIC:                         1.183e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# But look what happens to PCT_BA when I add PCT_GRAD_PROF into my original equation.
result = sm.ols(formula='MD_EARN_WNE_P10 ~ PCT_BA + PCT_GRAD_PROF + PCT_BORN_US + MEDIAN_HH_INC + POVERTY_RATE + UNEMP_RATE + PCT_WHITE + PCT_BLACK + PCT_ASIAN + PCT_HISPANIC - 1',data=df1).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        MD_EARN_WNE_P10   R-squared:                       0.782
# Model:                            OLS   Adj. R-squared:                  0.781
# Method:                 Least Squares   F-statistic:                     1895.
# Date:                Sat, 04 Aug 2018   Prob (F-statistic):               0.00
# Time:                        11:50:55   Log-Likelihood:                -59119.
# No. Observations:                5305   AIC:                         1.183e+05
# Df Residuals:                    5295   BIC:                         1.183e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
result = sm.ols(formula='MD_EARN_WNE_P10 ~ PCT_GRAD_PROF + MEDIAN_HH_INC + PCT_ASIAN - 1',data=df1).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        MD_EARN_WNE_P10   R-squared:                       0.781
# Model:                            OLS   Adj. R-squared:                  0.781
# Method:                 Least Squares   F-statistic:                     6309.
# Date:                Sat, 04 Aug 2018   Prob (F-statistic):               0.00
# Time:                        11:50:56   Log-Likelihood:                -59124.
# No. Observations:                5305   AIC:                         1.183e+05
# Df Residuals:                    5302   BIC:                         1.183e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...
