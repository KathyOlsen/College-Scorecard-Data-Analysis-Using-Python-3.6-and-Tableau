# %%
import pandas as pd
Location = "df1_2015_16.csv"
df = pd.read_csv(Location)
df.head()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
#                                 INSTNM        CITY STABBR         ZIP  HCM2  \
# 0             Alabama A & M University      Normal     AL       35762     0
# 1  University of Alabama at Birmingham  Birmingham     AL  35294-0110     0
# 2                   Amridge University  Montgomery     AL  36117-3553     0
# 3  University of Alabama in Huntsville  Huntsville     AL       35899     0
# 4             Alabama State University  Montgomery     AL  36104-0271     0
#
#    MAIN  NUMBRANCH  PREDDEG  HIGHDEG  CONTROL          ...           \
# ...

# %%
len(df)
# Out:
# 3905

# %%
# Note: "PrivacySuppressed" value in original dataset was replaced with 0 during clean up.   
# That may be replaced with mean or median, or row may be dropped.

# %%
df.describe()
# Out:
#               HCM2         MAIN    NUMBRANCH      PREDDEG      HIGHDEG  \
# count  3905.000000  3905.000000  3905.000000  3905.000000  3905.000000
# mean      0.004353     0.847119     3.438412     2.355186     3.057362
# std       0.065845     0.359919     8.188754     0.750402     0.900414
# min       0.000000     0.000000     1.000000     1.000000     2.000000
# 25%       0.000000     1.000000     1.000000     2.000000     2.000000
# 50%       0.000000     1.000000     1.000000     3.000000     3.000000
# 75%       0.000000     1.000000     1.000000     3.000000     4.000000
# max       1.000000     1.000000    79.000000     3.000000     4.000000
#
#            CONTROL      ST_FIPS       REGION  CURROPER       LOCALE  \
# count  3905.000000  3905.000000  3905.000000    3905.0  3905.000000
# mean      1.800768    29.510883     4.588220       1.0    20.605634
# std       0.769054    16.684818     2.159962       0.0    10.247234
# ...

# %%
df.corr()
# Out:
#                           HCM2      MAIN  NUMBRANCH   PREDDEG   HIGHDEG  \
# HCM2                  1.000000  0.028091  -0.019693 -0.005382  0.000107
# MAIN                  0.028091  1.000000  -0.599526  0.167910  0.088718
# NUMBRANCH            -0.019693 -0.599526   1.000000 -0.006214  0.051651
# PREDDEG              -0.005382  0.167910  -0.006214  1.000000  0.789452
# HIGHDEG               0.000107  0.088718   0.051651  0.789452  1.000000
# CONTROL               0.022191 -0.421002   0.371559 -0.068205  0.068665
# ST_FIPS              -0.038630 -0.030967  -0.010672  0.063798  0.043811
# REGION                0.018011 -0.080340   0.020738 -0.165756 -0.110601
# CURROPER                   NaN       NaN        NaN       NaN       NaN
# LOCALE               -0.017196  0.120120  -0.114654 -0.065490 -0.161034
# CCBASIC               0.016370  0.152380  -0.121884  0.591802  0.638228
# CCUGPROF              0.004776  0.141478  -0.060328  0.702610  0.766247
# ...

# %%
def relaffil(x):
    if x>0:
        return 1
    else:
        return 0

# %%
df['relaffil'] = df['RELAFFIL'].apply(relaffil)
df.head()
# Out:
#                                 INSTNM        CITY STABBR         ZIP  HCM2  \
# 0             Alabama A & M University      Normal     AL       35762     0
# 1  University of Alabama at Birmingham  Birmingham     AL  35294-0110     0
# 2                   Amridge University  Montgomery     AL  36117-3553     0
# 3  University of Alabama in Huntsville  Huntsville     AL       35899     0
# 4             Alabama State University  Montgomery     AL  36104-0271     0
#
#    MAIN  NUMBRANCH  PREDDEG  HIGHDEG  CONTROL    ...     RET_FTL4_POOLED_SUPP  \
# 0     1          1        3        4        1    ...                      NaN
# 1     1          1        3        4        1    ...                      NaN
# 2     1          1        3        4        2    ...                      NaN
# 3     1          1        3        4        1    ...                      NaN
# 4     1          1        3        4        1    ...                      NaN
#
# ...

# %%
df.to_csv('df1_2015_16_w_relaffil.csv',index=False)

# %%
import statsmodels.formula.api as sm
result = sm.ols(formula='OMAWDP8_FTFT ~ WOMENONLY + relaffil + ADM_RATE + SAT_AVG + AVGFACSAL + PCTFLOAN - 1',data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           OMAWDP8_FTFT   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     6360.
# Date:                Sat, 04 Aug 2018   Prob (F-statistic):               0.00
# Time:                        13:40:28   Log-Likelihood:                 1039.2
# No. Observations:                1251   AIC:                            -2066.
# Df Residuals:                    1245   BIC:                            -2036.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# WOMENONLY      0.0725      0.020      3.636      0.000       0.033       0.112
# ...

# %%
df2=df[df['SAT_AVG']==840]
df2.head()
# Out:
#                              INSTNM   CITY STABBR         ZIP  HCM2  MAIN  \
# 2409  Valley Forge Military College  Wayne     PA  19087-3695     0     1
#
#       NUMBRANCH  PREDDEG  HIGHDEG  CONTROL    ...     RET_FTL4_POOLED_SUPP  \
# 2409          1        2        2        2    ...                 0.794644
#
#       RET_PT4_POOLED_SUPP  RET_PTL4_POOLED_SUPP  TRANS_4_POOLED  \
# 2409                  NaN                   NaN             NaN
#
#       TRANS_L4_POOLED  DTRANS_4_POOLED  DTRANS_L4_POOLED  TRANS_4_POOLED_SUPP  \
# 2409         0.677966              NaN             295.0                  NaN
#
#       TRANS_L4_POOLED_SUPP  relaffil
# 2409              0.677966         0
#
# [1 rows x 643 columns]
